# %%
#importing different libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")   # ignore if any warnings are there

# %%
# loading the dataset
data = pd.read_csv(r"C:\Jupyter\DSML\DSML\Logistic Regression\candy-data.csv")
df = pd.DataFrame(data)
df.drop_duplicates(inplace=True) # drop duplicates if any.
df.shape # num rows x num columns.
# Out:
# (85, 13)

# %%
#Check for missing values
(df.isnull().sum()/len(df)*100).sort_values(ascending=False)
# Out:
# winpercent          0.0
# pricepercent        0.0
# sugarpercent        0.0
# pluribus            0.0
# bar                 0.0
# hard                0.0
# crispedricewafer    0.0
# nougat              0.0
# peanutyalmondy      0.0
# caramel             0.0
# fruity              0.0
# chocolate           0.0
# competitorname      0.0
# dtype: float64

# %%
df.head(3)
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086

# %%
df.describe()
# Out:
#        chocolate     fruity    caramel  peanutyalmondy     nougat  \
# count  85.000000  85.000000  85.000000       85.000000  85.000000
# mean    0.435294   0.447059   0.164706        0.164706   0.082353
# std     0.498738   0.500140   0.373116        0.373116   0.276533
# min     0.000000   0.000000   0.000000        0.000000   0.000000
# 25%     0.000000   0.000000   0.000000        0.000000   0.000000
# 50%     0.000000   0.000000   0.000000        0.000000   0.000000
# 75%     1.000000   1.000000   0.000000        0.000000   0.000000
# max     1.000000   1.000000   1.000000        1.000000   1.000000
#
#        crispedricewafer       hard        bar   pluribus  sugarpercent  \
# count         85.000000  85.000000  85.000000  85.000000     85.000000
# mean           0.082353   0.176471   0.247059   0.517647      0.478647
# std            0.276533   0.383482   0.433861   0.502654      0.282778
# min            0.000000   0.000000   0.000000   0.000000      0.011000
# 25%            0.000000   0.000000   0.000000   0.000000      0.220000
# 50%            0.000000   0.000000   0.000000   1.000000      0.465000
# 75%            0.000000   0.000000   0.000000   1.000000      0.732000
# max            1.000000   1.000000   1.000000   1.000000      0.988000
#
#        pricepercent  winpercent
# count     85.000000   85.000000
# mean       0.468882   50.316764
# std        0.285740   14.714357
# min        0.011000   22.445341
# 25%        0.255000   39.141056
# 50%        0.465000   47.829754
# 75%        0.651000   59.863998
# max        0.976000   84.180290

# %%
df['winpercent'] = df['winpercent']/100

# %%
df['sugarbyprice'] = df['sugarpercent'].div(df['pricepercent']) # higher value means the candy is sweet as well as cheap.
df['winbyprice'] = df['winpercent'].div(df['pricepercent']) # higher value means the candy is more liked as well as cheap.

# %%
df['competitorname'] = df['competitorname'].str.replace('Õ', "'") # Special character was appearing in name of candy.
df.sort_values(by=['winpercent', 'sugarpercent'], ascending=False).head()
#Reese's seem to be a favourite. Note that all the top competitors are chocolaty as well. 
#Also, Reese's Miniatures is very cheap when compared to top competitors and overall as well.
# Out:
#                competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 52  Reese's Peanut Butter cup          1       0        0               1
# 51         Reese's Miniatures          1       0        0               1
# 79                       Twix          1       0        1               0
# 28                    Kit Kat          1       0        0               0
# 64                   Snickers          1       0        1               1
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 52       0                 0     0    0         0         0.720         0.651
# 51       0                 0     0    0         0         0.034         0.279
# 79       0                 1     0    1         0         0.546         0.906
# 28       0                 1     0    1         0         0.313         0.511
# 64       1                 0     0    1         0         0.546         0.651
#
#     winpercent  sugarbyprice  winbyprice
# 52    0.841803      1.105991    1.293092
# 51    0.818663      0.121864    2.934274
# 79    0.816429      0.602649    0.901136
# 28    0.767686      0.612524    1.502321
# 64    0.766738      0.838710    1.177785

# %%
#Competitors which are not chocolaty but winners.
df[df['chocolate']==0].sort_values(by=['winpercent', 'sugarpercent'], ascending=False).head(10)
# Out:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 68                    Starburst          0       1        0               0
# 60            Skittles original          0       1        0               0
# 66              Sour Patch Kids          0       1        0               0
# 18            Haribo Gold Bears          0       1        0               0
# 41                        Nerds          0       1        0               0
# 61           Skittles wildberry          0       1        0               0
# 73                 Swedish Fish          0       1        0               0
# 31  Lifesavers big ring gummies          0       1        0               0
# 67        Sour Patch Tricksters          0       1        0               0
# 4                     Air Heads          0       1        0               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 68       0                 0     0    0         1         0.151         0.220
# 60       0                 0     0    0         1         0.941         0.220
# 66       0                 0     0    0         1         0.069         0.116
# 18       0                 0     0    0         1         0.465         0.465
# 41       0                 0     1    0         1         0.848         0.325
# 61       0                 0     0    0         1         0.941         0.220
# 73       0                 0     0    0         1         0.604         0.755
# 31       0                 0     0    0         0         0.267         0.279
# 67       0                 0     0    0         1         0.069         0.116
# 4        0                 0     0    0         0         0.906         0.511
#
#     winpercent  sugarbyprice  winbyprice
# 68    0.670376      0.686364    3.047165
# 60    0.630851      4.277273    2.867506
# 66    0.598640      0.594828    5.160689
# 18    0.571197      1.000000    1.228382
# 41    0.553540      2.609231    1.703201
# 61    0.551037      4.277273    2.504713
# 73    0.548611      0.800000    0.726637
# 31    0.529114      0.956989    1.896466
# 67    0.528259      0.594828    4.553961
# 4     0.523415      1.772994    1.024295

# %%
#checking the corelation between all the independent columns
df.corr().abs().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col1 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col2 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col3 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col4 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col5 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col6 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col7 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col8 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col9 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col10 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col11 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col12 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row0_col13 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col0 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col2 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col3 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col4 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col5 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col6 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col7 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col8 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col10 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col11 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col12 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col0 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col1 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col3 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col4 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col5 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col6 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col7 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col8 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col9 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col10 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col11 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col12 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row2_col13 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col0 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col1 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col6 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col7 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col8 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col9 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col10 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col11 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col12 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row3_col13 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row4_col0 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row4_col1 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row4_col2 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_b256d170_e1ea_11e9_bf4a_a08cfd4f1bb7row4_col3 {
#             background-color:  #7a9df8;
#             colo

# %%
# Create correlation matrix
corr_matrix = df.corrwith(df.chocolate).abs()
corr_matrix
# Out:
# chocolate           1.000000
# fruity              0.741721
# caramel             0.249875
# peanutyalmondy      0.377824
# nougat              0.254892
# crispedricewafer    0.341210
# hard                0.344177
# bar                 0.597421
# pluribus            0.339675
# sugarpercent        0.104169
# pricepercent        0.504675
# winpercent          0.636517
# sugarbyprice        0.158692
# winbyprice          0.029718
# dtype: float64

# %%
#Remove columns which have less correlation to chocolate 
df=df.drop(['competitorname','caramel', 'peanutyalmondy','nougat','crispedricewafer','hard','pluribus','sugarpercent','sugarbyprice','winbyprice'], axis = 1)

# %%
df.head(3)
# Out:
#    chocolate  fruity  bar  pricepercent  winpercent
# 0          1       0    1         0.860    0.669717
# 1          1       0    1         0.511    0.676029
# 2          0       0    0         0.116    0.322611

# %%
x=df.drop('chocolate',axis=1)
y=df.chocolate

# %%
#spiltting the dataset into train and test dataset
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=101)

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#predecting the value of y_pred
y_pred = model.predict(x_test)

# %%
#checking the accuracy score
accuracy_score(y_pred,y_test)
# Out:
# 0.9310344827586207

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        16
#            1       1.00      0.85      0.92        13
#
#    micro avg       0.93      0.93      0.93        29
#    macro avg       0.94      0.92      0.93        29
# weighted avg       0.94      0.93      0.93        29

# %%
print(confusion_matrix(y_pred,y_test))
# Out:
# [[16  0]
#  [ 2 11]]
