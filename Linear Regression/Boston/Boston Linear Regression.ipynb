# %% [markdown]
# House Pricing Linear Regression

# %%
#importing important libraries
import numpy as np
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.datasets import load_boston  # loading the boston dataset from the sklearn.datasets

# %%
# loading the important columns dependent columns and values from the boston dataset
boston = load_boston()
data =boston.data
boston_column = boston.feature_names
Target = boston.target

# %%
#Description of the Boston dataset
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
#putting independent columns in the df dataframe and target value in the target dataFrame
df =pd.DataFrame(data,columns=boston_column)
Target = pd.DataFrame(Target,columns=['MDEV'])

# %%
# first 3 rows of the boston data set
df.head(3)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03

# %%
# first 3 rows of the target dataframe
Target.head(3)
# Out:
#    MDEV
# 0  24.0
# 1  21.6
# 2  34.7

# %%
# checking the information of the Boston dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null float64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null float64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
#distribution plot of the target variable
plt.figure(figsize=(15,8))
sbn.distplot(Target['MDEV'])

# %%
#checking the corelation between all the independent columns
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col1 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col2 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col4 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col6 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col7 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col8 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col9 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col10 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col11 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row0_col12 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col0 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col2 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col3 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col5 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col6 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col7 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col8 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col9 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col11 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row1_col12 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col0 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col1 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col4 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col5 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col6 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col8 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col9 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col10 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col11 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row2_col12 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col0 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col1 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col2 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col4 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col5 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col6 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col7 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col8 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col9 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col10 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col11 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row3_col12 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row4_col0 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row4_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row4_col2 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row4_col3 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row4_col5 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row4_col6 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_e24df95a_e018_11e9_9ae6_a08cfd4f1bb7row4_col7 {
#             background-color:  #3b4cc0;
#             color:

# %%
x=df
y=Target

# %%
# genearting the test and train datasets
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.33,random_state=105)

# %%
model = LinearRegression()

# %%
# fitting the model
Fit = model.fit(x_train,y_train)

# %%
#predicting the value from the fitted model by giving the x_test value
y_pred = model.predict(x_test)

# %%
print(Fit.intercept_)
# Out:
# [33.82172858]

# %%
# R2 score value which is the evaluation metrices for linear Regression model
r2_score(y_test,y_pred)
# Out:
# 0.752095922111238

# %%
# evalution metrix
mean_squared_error(y_test,y_pred)
# Out:
# 22.96730649774997
